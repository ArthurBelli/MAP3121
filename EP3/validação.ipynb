u_obtido_63 = [0.0, 0.0001529346812854958, 0.00043573644426130785, 0.0008752743403116394, 0.0015489850381407455, 0.002329978075894365, 0.0032590302554042923, 0.004354450437757596, 0.0055358975824682365, 0.006849039684642305, 0.008273460648276434, 0.00976398256089935, 0.011363188425699682, 0.013030259296147309, 0.014744834466413802, 0.01653947613456009, 0.018369203866129925, 0.020229889888955827, 0.02213601632551685, 0.024054765701293647, 0.025988817214965505, 0.027931036371172942, 0.029871530003017496, 0.03180681455014896, 0.03372287750244102, 0.03562419583099016, 0.037495979154952425, 0.03932999480854338, 0.04113757610320999, 0.042888522148131845, 0.044590957237011966, 0.04625659759598499, 0.04783676850675281, 0.04936444759368844, 0.05084281617944838, 0.052213157066190556, 0.05352926254272407, 0.05477582083807997, 0.05591024052012997, 0.05698431260657978, 0.05796761825831195, 0.058840685420565586, 0.05964862216602616, 0.060344631021672465, 0.06093727217780162, 0.061461329460143474, 0.061853395567999375, 0.06215289506045198, 0.06238168658632165, 0.062460562195440175, 0.06246056219544019, 0.06238168658632167, 0.062152895060452025, 0.06185339556799943, 0.06146132946014353, 0.06093727217780169, 0.060344631021672535, 0.05964862216602623, 0.058840685420565655, 0.057967618258312016, 0.056984312606579865, 0.05591024052013004, 0.054775820838080067, 0.053529262542724165, 0.05221315706619066, 0.0508428161794485, 0.04936444759368856, 0.04783676850675294, 0.04625659759598512, 0.044590957237012105, 0.04288852214813198, 0.04113757610321012, 0.0393299948085435, 0.03749597915495254, 0.03562419583099028, 0.033722877502441115, 0.03180681455014905, 0.029871530003017593, 0.027931036371173022, 0.025988817214965584, 0.024054765701293716, 0.022136016325516927, 0.020229889888955885, 0.018369203866129988, 0.01653947613456016, 0.014744834466413852, 0.013030259296147364, 0.011363188425699725, 0.009763982560899397, 0.008273460648276467, 0.006849039684642342, 0.005535897582468273, 0.004354450437757621, 0.0032590302554043197, 0.0023299780758943805, 0.0015489850381407617, 0.0008752743403116545, 0.00043573644426131463, 0.0001529346812855005, 0.0]
max_error_63 = max([abs(u_teor[i]-u_obtido_63[i]) for i in range(len(eixox))])

print(f"max_error_7 = {max_error_7}\nmax_error_15 = {max_error_15}\nmax_error_31 = {max_error_31}\nmax_error_63 = {max_error_63}\n")
err = [max_error_7, max_error_15, max_error_31, max_error_63]
# Out:
# max_error_7 = 0.002558826773663678
# max_error_15 = 0.0008011312466349996
# max_error_31 = 0.00020067415627016502
# max_error_63 = 5.295508632549318e-05

# %%
plt.plot(eixox, u_teor, 'r')
plt.plot(eixox, u_obtido_7, 'b')
plt.title("N=7")
plt.xlabel("L")
plt.ylabel("Temperatura")
plt.legend(["u_teórico", "u_obtido_7"], loc="upper left")
plt.savefig("u_7.png")
plt.show()

# %%
plt.plot(eixox, u_teor, 'r')
plt.plot(eixox, u_obtido_15, 'b')
plt.title("N=15")
plt.xlabel("L")
plt.ylabel("Temperatura")
plt.legend(["u_teórico", "u_obtido_15"], loc="upper left")
plt.savefig("u_15.png")
plt.show()

# %%
plt.plot(eixox, u_teor, 'r')
plt.plot(eixox, u_obtido_31, 'b')
plt.title("N=31")
plt.xlabel("L")
plt.ylabel("Temperatura")
plt.legend(["u_teórico", "u_obtido_31"], loc="upper left")
plt.savefig("u_31.png")
plt.show()

# %%
plt.plot(eixox, u_teor, 'r')
plt.plot(eixox, u_obtido_63, 'b')
plt.title("N=63")
plt.xlabel("L")
plt.ylabel("Temperatura")
plt.legend(["u_teórico", "u_obtido_63"], loc="upper left")
plt.savefig("u_63.png")
plt.show()

# %%
x = [7, 15, 31, 63]
plt.plot(x, err, 'blue')
plt.title("Erro em função do número de apoios")
plt.savefig("erro.png")
plt.show()

# %% [markdown]
# ## Equilíbrio com forçantes de calor
